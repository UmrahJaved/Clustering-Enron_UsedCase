# %% [markdown]
# # Creating DataFrame
# <br> 1. Loading RAW data
# <br> 2. Converting it to DataFrame and creating relevant columns from the content
# <br> 3. Deleting rows with empty values
# <br> 4. Save the DataFrame to a file for easy opening (no need to convert it every time)

# %%
import email
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from subprocess import check_output

# %%
pd.options.mode.chained_assignment = None
emails_df = pd.read_csv('data/emails.csv')

# %%
emails_df.head()
# Out:
#                        file                                            message
# 0     allen-p/_sent_mail/1.  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1    allen-p/_sent_mail/10.  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2   allen-p/_sent_mail/100.  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3  allen-p/_sent_mail/1000.  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4  allen-p/_sent_mail/1001.  Message-ID: <30922949.1075863688243.JavaMail.e...

# %%
def get_text_from_email(msg: email.message.Message) -> str:
    """To get the content from email objects
    :param msg: the email object
    :return: the content of the email
    """
    parts = []
    for part in msg.walk():
        if part.get_content_type() == 'text/plain':
            parts.append( part.get_payload() )
    return ''.join(parts)

def split_email_addresses(line: str) -> frozenset:
    """
    To separate multiple email addresses
    :param line: the line of the csv file
    :return: a set of email addresses
    """
    if line:
        addrs = line.split(',')
        addrs = frozenset(map(lambda x: x.strip(), addrs))
    else:
        addrs = None
    return addrs

# %%
# Parse the emails into a list email objects
messages = list(map(email.message_from_string, emails_df['message']))
emails_df.drop('message', axis=1, inplace=True)

# Get fields from parsed email objects
keys = messages[0].keys()
for key in keys:
    emails_df[key] = [doc[key] for doc in messages]

# Parse content from emails
emails_df['content'] = list(map(get_text_from_email, messages))

# Split multiple email addresses
emails_df['From'] = emails_df['From'].map(split_email_addresses)
emails_df['To'] = emails_df['To'].map(split_email_addresses)

# Extract the root of 'file' as 'user'
emails_df['user'] = emails_df['file'].map(lambda x:x.split('/')[0])
del messages

# %%
emails_df.isnull().sum()
# Out:
# file                             0
# Message-ID                       0
# Date                             0
# From                             0
# To                           21847
# Subject                          0
# Mime-Version                    29
# Content-Type                    29
# Content-Transfer-Encoding       29
# X-From                          29
# X-To                            29
# X-cc                            29
# X-bcc                           29
# X-Folder                        29
# X-Origin                        29
# X-FileName                      29
# content                          0
# user                             0
# dtype: int64

# %%
#emails_df find null rows
emails_df.loc[emails_df['To'].isnull()]
# Out:
#                                  file  \
# 188           allen-p/_sent_mail/264.
# 603         allen-p/all_documents/10.
# 781        allen-p/all_documents/263.
# 873        allen-p/all_documents/348.
# 885        allen-p/all_documents/359.
# ...                               ...
# 516846         zufferli-j/calendar/1.
# 516867  zufferli-j/deleted_items/112.
# 516878  zufferli-j/deleted_items/123.
# 516927   zufferli-j/deleted_items/58.
# 516976           zufferli-j/inbox/12.
#
#                                            Message-ID  \
# 188     <15201149.1075855691021.JavaMail.evans@thyme>
# 603     <21975671.1075855665520.JavaMail.evans@thyme>
# 781      <9828978.1075855671241.JavaMail.evans@thyme>
# 873      <8236042.1075855673105.JavaMail.evans@thyme>
# 885     <26959382.1075855693279.JavaMail.evans@thyme>
# ...                                               ...
# 516846  <28390332.1075842024763.JavaMail.evans@thyme>
# 516867  <32471560.1075842024421.JavaMail.evans@thyme>
# 516878  <24228255.1075842024716.JavaMail.evans@thyme>
# 516927  <27830378.1075842022474.JavaMail.evans@thyme>
# 516976   <7647418.1075842025228.JavaMail.evans@thyme>
#
#                                          Date                           From  \
# 188      Mon, 1 May 2000 03:56:00 -0700 (PDT)      (phillip.allen@enron.com)
# 603     Wed, 13 Dec 2000 08:35:00 -0800 (PST)  (messenger@ecm.bloomberg.com)
# 781      Mon, 1 May 2000 03:56:00 -0700 (PDT)      (phillip.allen@enron.com)
# 873      Fri, 7 Jan 2000 16:23:00 -0800 (PST)    (owner-strawbale@crest.org)
# 885     Mon, 14 May 2001 09:04:00 -0700 (PDT)  (messenger@ecm.bloomberg.com)
# ...                                       ...                            ...
# 516846   Tue, 5 Feb 2002 09:43:01 -0800 (PST)      (john.zufferli@enron.com)
# 516867  Fri, 25 Jan 2002 14:18:55 -0800 (PST)         (no.address@enron.com)
# 516878  Mon, 21 Jan 2002 16:59:41 -0800 (PST)   (david_paul_smith@attbi.com)
# 516927  Thu, 31 Jan 2002 13:22:01 -0800 (PST)         (no.address@enron.com)
# 516976   Wed, 6 Feb 2002 08:02:18 -0800 (PST)        (janet.mulero@ubsw.com)
#
#           To                                        Subject Mime-Version  \
# 188     None                              Re: DSL- Installs          1.0
# 603     None                   Bloomberg Power Lines Report          1.0
# 781     None                              Re: DSL- Installs          1.0
# 873     None                                                         1.0
# 885     None                   Bloomberg Power Lines Report          1.0
# ...      ...                                            ...          ...
# 516846  None                                                         1.0
# 516867  None      Weekend Outage Report for 1/25/02-1/27/02          1.0
# 516878  None                    "less busy" Head Trip flyer          1.0
# 516927  None      Weekend Outage Report for 2/1/02 - 2/3/02          1.0
# 516976  None  Re: Market Risk Meeting Today - John Zufferli          1.0
#
#                               Content-Type Content-Transfer-Encoding  \
# 188           text/plain; charset=us-ascii                      7bit
# 603     text/plain; charset=ANSI_X3.4-1968          quoted-printable
# 781           text/plain; charset=us-ascii                      7bit
# 873           text/plain; charset=us-ascii                      7bit
# 885     text/plain; charset=ANSI_X3.4-1968          quoted-printable
# ...                                    ...                       ...
# 516846        text/plain; charset=us-ascii                      7bit
# 516867        text/plain; charset=us-ascii                      7bit
# 516878        text/plain; charset=us-ascii                      7bit
# 516927        text/plain; charset=us-ascii                      7bit
# 516976        text/plain; charset=us-ascii                      7bit
#
#                                                    X-From  \
# 188                                       Phillip K Allen
# 603         "Bloomberg.com" <messenger@ecm.bloomberg.com>
# 781                                       Phillip K Allen
# 873                             owner-strawbale@crest.org
# 885         "Bloomberg.com" <messenger@ecm.bloomberg.com>
# ...                                                   ...
# 516846  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 516867         Enron Change Management Announcement@ENRON
# 516878                   david_paul_smith@attbi.com@ENRON
# 516927         Enron Change Management Announcement@ENRON
# 516976                        Janet.Mulero@ubsw.com@ENRON
#
#                                   X-To  \
# 188         Circuit Provisioning@ENRON
# 603           (undisclosed-recipients)
# 781         Circuit Provisioning@ENRON
# 873          undisclosed-recipients:,
# 885           (undisclosed-recipients)
# ...                                ...
# 516846
# 516867     Houston Outage Report@ENRON
# 516878  undisclosed-recipients:;@ENRON
# 516927     Houston Outage Report@ENRON
# 516976
#
#                                                      X-cc X-bcc  \
# 188
# 603
# 781
# 873
# 885
# ...                                                   ...   ...
# 516846
# 516867
# 516878
# 516927
# 516976  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
#
#                                                  X-Folder    X-Origin  \
# 188       \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 603     \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P
# 781     \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P
# 873     \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P
# 885     \Phillip_Allen_June2001\Notes Folders\All docu...     Allen-P
# ...                                                   ...         ...
# 516846                 \ExMerge - Zufferli, John\Calendar  ZUFFERLI-J
# 516867            \ExMerge - Zufferli, John\Deleted Items  ZUFFERLI-J
# 516878            \ExMerge - Zufferli, John\Deleted Items  ZUFFERLI-J
# 516927            \ExMerge - Zufferli, John\Deleted Items  ZUFFERLI-J
# 516976                    \ExMerge - Zufferli, John\Inbox  ZUFFERLI-J
#
#                        X-FileName  \
# 188                    pallen.nsf
# 603                    pallen.nsf
# 781                    pallen.nsf
# 873                    pallen.nsf
# 885                    pallen.nsf
# ...                           ...
# 516846  john zufferli 6-26-02.PST
# 516867  john zufferli 6-26-02.PST
# 516878  john zufferli 6-26-02.PST
# 516927  john zufferli 6-26-02.PST
# 516976  john zufferli 6-26-02.PST
#
#                                                   content        user
# 188     No one will be home on 5/11/00 to meet DSL ins...     allen-p
# 603     Here is today's copy of Bloomberg Power Lines....     allen-p
# 781     No one will be home on 5/11/00 to meet DSL ins...     allen-p
# 873     <4DDE116DBCA1D3118B130080C840BAAD02CD53@ppims....     allen-p
# 885     Here is today's copy of Bloomberg Power Lines....     allen-p
# ...                                                   ...         ...
# 516846                           Conference call with UBS  zufferli-j
# 516867  ______________________________________________...  zufferli-j
# 516878  Howdy!\n\nHere's a better "less busy" flyer to...  zufferli-j
# 516927  ______________________________________________...  zufferli-j
# 516976       Hi.\n\n     The Market Risk Meeting has b...  zufferli-j
#
# [21847 rows x 18 columns]

# %%
# remove rows with null values
emails_df = emails_df.dropna()

# %%
emails_df.isnull().sum()
# Out:
# file                         0
# Message-ID                   0
# Date                         0
# From                         0
# To                           0
# Subject                      0
# Mime-Version                 0
# Content-Type                 0
# Content-Transfer-Encoding    0
# X-From                       0
# X-To                         0
# X-cc                         0
# X-bcc                        0
# X-Folder                     0
# X-Origin                     0
# X-FileName                   0
# content                      0
# user                         0
# dtype: int64

# %%
emails_df.shape
# Out:
# (495547, 18)

# %%
# save dataframe to file
emails_df.to_csv('data/emails_df.csv', index=False)

# %%
# open dataframe from file
emails_df_2 = pd.read_csv('data/emails_df.csv')

# %%
emails_df_2.head()
# Out:
#                        file                                     Message-ID  \
# 0     allen-p/_sent_mail/1.  <18782981.1075855378110.JavaMail.evans@thyme>
# 1    allen-p/_sent_mail/10.  <15464986.1075855378456.JavaMail.evans@thyme>
# 2   allen-p/_sent_mail/100.  <24216240.1075855687451.JavaMail.evans@thyme>
# 3  allen-p/_sent_mail/1000.  <13505866.1075863688222.JavaMail.evans@thyme>
# 4  allen-p/_sent_mail/1001.  <30922949.1075863688243.JavaMail.evans@thyme>
#
#                                     Date  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)
#
#                                      From  \
# 0  frozenset({'phillip.allen@enron.com'})
# 1  frozenset({'phillip.allen@enron.com'})
# 2  frozenset({'phillip.allen@enron.com'})
# 3  frozenset({'phillip.allen@enron.com'})
# 4  frozenset({'phillip.allen@enron.com'})
#
#                                        To    Subject  Mime-Version  \
# 0     frozenset({'tim.belden@enron.com'})        NaN           1.0
# 1  frozenset({'john.lavorato@enron.com'})        Re:           1.0
# 2   frozenset({'leah.arsdall@enron.com'})   Re: test           1.0
# 3    frozenset({'randall.gay@enron.com'})        NaN           1.0
# 4     frozenset({'greg.piper@enron.com'})  Re: Hello           1.0
#
#                    Content-Type Content-Transfer-Encoding           X-From  \
# 0  text/plain; charset=us-ascii                      7bit  Phillip K Allen
# 1  text/plain; charset=us-ascii                      7bit  Phillip K Allen
# 2  text/plain; charset=us-ascii                      7bit  Phillip K Allen
# 3  text/plain; charset=us-ascii                      7bit  Phillip K Allen
# 4  text/plain; charset=us-ascii                      7bit  Phillip K Allen
#
#                                                 X-To X-cc X-bcc  \
# 0           Tim Belden <Tim Belden/Enron@EnronXGate>  NaN   NaN
# 1  John J Lavorato <John J Lavorato/ENRON@enronXg...  NaN   NaN
# 2                                   Leah Van Arsdall  NaN   NaN
# 3                                      Randall L Gay  NaN   NaN
# 4                                         Greg Piper  NaN   NaN
#
#                                             X-Folder X-Origin  \
# 0  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 1  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 2    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 3    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 4    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
#
#                     X-FileName  \
# 0  pallen (Non-Privileged).pst
# 1  pallen (Non-Privileged).pst
# 2                   pallen.nsf
# 3                   pallen.nsf
# 4                   pallen.nsf
#
#                                              content     user
# 0                          Here is our forecast\n\n   allen-p
# 1  Traveling to have a business meeting takes the...  allen-p
# 2                     test successful.  way to go!!!  allen-p
# 3  Randy,\n\n Can you send me a schedule of the s...  allen-p
# 4                Let's shoot for Tuesday at 11:45.    allen-p
